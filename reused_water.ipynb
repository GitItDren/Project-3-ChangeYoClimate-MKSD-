# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import linregress
import numpy as np

reused_h2o_path = "data\\clean_data\\natural_reasources\\water_use\\Total_abstractions_of_reused_water.csv"
#read csv file into dataframe
reused_h2o_csv = pd.read_csv(reused_h2o_path)

# %%
reused_h2o_csv.head()
# Out:
#     ObjectId    country continent                        h20_variable  year  \
# 0   91264441  Australia   Oceania  Total abstractions of reused water  2001
# 1  435582420  Australia   Oceania  Total abstractions of reused water  2005
# 2  415802382  Australia   Oceania  Total abstractions of reused water  2009
# 3  736233665  Australia   Oceania  Total abstractions of reused water  2010
# 4   16766311  Australia   Oceania  Total abstractions of reused water  2011
#
#        h20_unit  h20_powercode_code h20_powercode  h20_value h20_flags
# 0  Cubic metres                   6      Millions    506.920       NaN
# 1  Cubic metres                   6      Millions    424.615       NaN
# 2  Cubic metres                   6      Millions    327.000       NaN
# 3  Cubic metres                   6      Millions    340.000       NaN
# 4  Cubic metres                   6      Millions    351.000       NaN

# %%
columns = reused_h2o_csv[['continent', 'year', 'h20_value']]

columns
# Out:
#     continent  year  h20_value
# 0     Oceania  2001    506.920
# 1     Oceania  2005    424.615
# 2     Oceania  2009    327.000
# 3     Oceania  2010    340.000
# 4     Oceania  2011    351.000
# ..        ...   ...        ...
# 346    Europe  2017    632.500
# 347    Europe  2018    676.900
# 348    Europe  2019    612.900
# 349    Europe  2020    536.104
# 350    Europe  2021    633.552
#
# [351 rows x 3 columns]

# %%
continent = 'Asia'

continent_data = reused_h2o_csv[reused_h2o_csv['continent'] == continent]

average_year = continent_data.groupby('year')['h20_value'].mean().reset_index()

average_year.columns = ['Year', 'Average_h20']


plt.figure(figsize=(10, 6))
plt.bar(average_year['Year'], average_year['Average_h20'], color='teal', alpha=0.6)
plt.xlabel('Year')
plt.ylabel('Average Water Abstraction (h20_value)')
plt.title(f'Average Water Abstraction Over the Years in {continent}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("reused_water_asia.png")
plt.show()

# %%
continent = 'North America'

continent_data = reused_h2o_csv[reused_h2o_csv['continent'] == continent]

average_year = continent_data.groupby('year')['h20_value'].mean().reset_index()

average_year.columns = ['Year', 'Average_h20']


plt.figure(figsize=(10, 6))
plt.bar(average_year['Year'], average_year['Average_h20'], color='teal', alpha=0.6)
plt.xlabel('Year')
plt.ylabel('Average Water Abstraction (h20_value)')
plt.title(f'Average Water Abstraction Over the Years in {continent}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("reused_water_north.png")
plt.show()

# %%
continent = 'Oceania'

continent_data = reused_h2o_csv[reused_h2o_csv['continent'] == continent]

average_year = continent_data.groupby('year')['h20_value'].mean().reset_index()

average_year.columns = ['Year', 'Average_h20']


plt.figure(figsize=(10, 6))
plt.bar(average_year['Year'], average_year['Average_h20'], color='teal', alpha=0.6)
plt.xlabel('Year')
plt.ylabel('Average Water Abstraction (h20_value)')
plt.title(f'Average Water Abstraction Over the Years in {continent}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("reused_water_oceania.png")
plt.show()

# %%
continent = 'Oceania'

continent_data = reused_h2o_csv[reused_h2o_csv['continent'] == continent]

average_year = continent_data.groupby('year')['h20_value'].mean().reset_index()

average_year.columns = ['Year', 'Average_h20']

plt.figure(figsize=(10, 6))
plt.scatter(average_year['Year'], average_year['Average_h20'], color='steelblue', alpha=0.6, label='Data Points')
slope, intercept, r_value, p_value, std_err = stats.linregress(average_year['Year'], average_year['Average_h20'])
line = slope * average_year['Year'] + intercept

plt.plot(average_year['Year'], line, color='red', label=f'Linear Regression (r-squared={r_value**2:.4f})')

plt.xlabel('Year')
plt.ylabel('Average Water Abstraction (h20_value)')
plt.title(f'Scatter Plot with Linear Regression in {continent}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("reused_water_oceania_scat.png")
plt.show()

# %%
continent = 'North America'

continent_data = reused_h2o_csv[reused_h2o_csv['continent'] == continent]

average_year = continent_data.groupby('year')['h20_value'].mean().reset_index()

average_year.columns = ['Year', 'Average_h20']

plt.figure(figsize=(10, 6))
plt.scatter(average_year['Year'], average_year['Average_h20'], color='steelblue', alpha=0.6, label='Data Points')
slope, intercept, r_value, p_value, std_err = stats.linregress(average_year['Year'], average_year['Average_h20'])
line = slope * average_year['Year'] + intercept

plt.plot(average_year['Year'], line, color='red', label=f'Linear Regression (r-squared={r_value**2:.4f})')

plt.xlabel('Year')
plt.ylabel('Average Water Abstraction (h20_value)')
plt.title(f'Scatter Plot with Linear Regression in {continent}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("reused_water_north_scat.png")
plt.show()

# %%
continent = 'Asia'

continent_data = reused_h2o_csv[reused_h2o_csv['continent'] == continent]

average_year = continent_data.groupby('year')['h20_value'].mean().reset_index()

average_year.columns = ['Year', 'Average_h20']

plt.figure(figsize=(10, 6))
plt.scatter(average_year['Year'], average_year['Average_h20'], color='steelblue', alpha=0.6, label='Data Points')
slope, intercept, r_value, p_value, std_err = stats.linregress(average_year['Year'], average_year['Average_h20'])
line = slope * average_year['Year'] + intercept

plt.plot(average_year['Year'], line, color='red', label=f'Linear Regression (r-squared={r_value**2:.4f})')

plt.xlabel('Year')
plt.ylabel('Average Water Abstraction (h20_value)')
plt.title(f'Scatter Plot with Linear Regression in {continent}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("reused_water_asia_scat.png")
plt.show()
